# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in d:\conda\lib\site-packages (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in d:\conda\lib\site-packages (from tensorflow) (2.16.1)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.2.0)
# Requirement already satisfied: flatbuffers>=23.5.26 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.3)
# Requirement already satisfied: packaging in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (23.2)
# Requirement already satisfied: astunparse>=1.6.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.6.3)
# Requirement already satisfied: keras>=3.0.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.2.1)
# Requirement already satisfied: setuptools in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (61.2.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.16.2)
# Requirement already satisfied: six>=1.12.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.31.0)
# Requirement already satisfied: ml-dtypes~=0.3.1 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.3.2)
# Requirement already satisfied: termcolor>=1.1.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.9.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.62.2)
# Requirement already satisfied: wrapt>=1.11.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: h5py>=3.10.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.11.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (0.5.4)
# Requirement already satisfied: libclang>=13.0.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (18.1.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\conda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.37.1)
# Requirement already satisfied: rich in d:\conda\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.7.1)
# Requirement already satisfied: namex in d:\conda\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.0.8)
# Requirement already satisfied: optree in d:\conda\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.11.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (1.26.8)
# Requirement already satisfied: markdown>=2.6.8 in d:\conda\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\conda\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\conda\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\conda\lib\site-packages (from markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (7.0.1)
# Requirement already satisfied: zipp>=0.5 in d:\conda\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\conda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\conda\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\conda\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in d:\conda\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tf_keras
# Out:
# Requirement already satisfied: tf_keras in d:\conda\lib\site-packages (2.16.0)
# Requirement already satisfied: tensorflow<2.17,>=2.16 in d:\conda\lib\site-packages (from tf_keras) (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in d:\conda\lib\site-packages (from tensorflow<2.17,>=2.16->tf_keras) (2.16.1)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.5.4)
# Requirement already satisfied: astunparse>=1.6.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.31.0)
# Requirement already satisfied: packaging in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (23.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.62.2)
# Requirement already satisfied: ml-dtypes~=0.3.1 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.3.2)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.31.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (4.25.3)
# Requirement already satisfied: wrapt>=1.11.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.16.0)
# Requirement already satisfied: h5py>=3.10.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (4.9.0)
# Requirement already satisfied: six>=1.12.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.16.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.26.4)
# Requirement already satisfied: setuptools in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (61.2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.1.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.16.2)
# Requirement already satisfied: libclang>=13.0.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (18.1.1)
# Requirement already satisfied: flatbuffers>=23.5.26 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (24.3.25)
# Requirement already satisfied: keras>=3.0.0 in d:\conda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.2.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\conda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.37.1)
# Requirement already satisfied: namex in d:\conda\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.0.8)
# Requirement already satisfied: optree in d:\conda\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.11.0)
# Requirement already satisfied: rich in d:\conda\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (13.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in d:\conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\conda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in d:\conda\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\conda\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\conda\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.0.2)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\conda\lib\site-packages (from markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (7.0.1)
# Requirement already satisfied: zipp>=0.5 in d:\conda\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\conda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.1.3)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\conda\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (2.15.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\conda\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in d:\conda\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow<2.17,>=2.16->tf_keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %set_env TF_USE_LEGACY_KERAS=True
# Out:
# env: TF_USE_LEGACY_KERAS=True

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    r'C:\Users\user\archive\New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 70295 files belonging to 38 classes.

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    r'C:\Users\user\archive\New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=32,
    image_size=(128, 128),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 17572 files belonging to 38 classes.

# %%
from tensorflow.keras.layers import Dense,Conv2D,Flatten
from tensorflow.keras.models import Sequential

# %%
model=Sequential()

# %%
cnn = tf.keras.models.Sequential()
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, padding='same', activation='relu', input_shape=[128, 128, 3]))
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=128,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=128,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=256,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=256,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Conv2D(filters=512,kernel_size=3,padding='same',activation='relu'))
cnn.add(tf.keras.layers.Conv2D(filters=512,kernel_size=3,activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2))

# %%
cnn.add(tf.keras.layers.Dropout(0.25))

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(units=1500,activation='relu'))

# %%
cnn.add(tf.keras.layers.Dropout(0.4)) #To avoid overfitting

# %%
#Output Layer
cnn.add(tf.keras.layers.Dense(units=38,activation='softmax'))

# %%
cnn.compile(optimizer=tf.keras.optimizers.Adam(
    learning_rate=0.0001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
cnn.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_27 (Conv2D)              │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_28 (Conv2D)              │ (None, 126, 126, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_29 (Conv2D)              │ (None, 63, 63, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_30 (Conv2D)              │ (None, 61, 61, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_31 (Conv2D)              │ (None, 30, 30, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_32 (Conv2D)              │ (None, 28, 28, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_33 (Conv2D)              │ (None, 14, 14, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_34 (Conv2D)              │ (None, 12, 12, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_35 (Conv2D)              │ (None, 6, 6, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_36 (Conv2D)              │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1500)           │     3,073,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 1500)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 38)             │        57,038 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,842,762 (29.92 MB)
#  Trainable params: 7,842,762 (29.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
training_history = cnn.fit(x=training_set,validation_data=validation_set,epochs=10)
# Out:
# Epoch 1/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 1402s 634ms/step - accuracy: 0.4123 - loss: 2.0766 - val_accuracy: 0.8528 - val_loss: 0.4632
# Epoch 2/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 1325s 603ms/step - accuracy: 0.8426 - loss: 0.4967 - val_accuracy: 0.9092 - val_loss: 0.2774
# Epoch 3/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 1328s 604ms/step - accuracy: 0.9078 - loss: 0.2839 - val_accuracy: 0.9402 - val_loss: 0.1820
# Epoch 4/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 1330s 605ms/step - accuracy: 0.9388 - loss: 0.1849 - val_accuracy: 0.9443 - val_loss: 0.1676
# Epoch 5/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 1327s 604ms/step - accuracy: 0.9552 - loss: 0.1397 - val_accuracy: 0.9548 - val_loss: 0.1451
# Epoch 6/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 1311s 597ms/step - accuracy: 0.9638 - loss: 0.1127 - val_accuracy: 0.9621 - val_loss: 0.1250
# Epoch 7/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 1316s 599ms/step - accuracy: 0.9712 - loss: 0.0869 - val_accuracy: 0.9637 - val_loss: 0.1170
# Epoch 8/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 1321s 601ms/step - accuracy: 0.9766 - loss: 0.0715 - val_accuracy: 0.9570 - val_loss: 0.1368
# Epoch 9/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 1306s 594ms/step - accuracy: 0.9809 - loss: 0.0600 - val_accuracy: 0.9662 - val_loss: 0.1157
# Epoch 10/10
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 1309s 596ms/step - accuracy: 0.9812 - loss: 0.0573 - val_accuracy: 0.9677 - val_loss: 0.1118

# %%
#Training set Accuracy
train_loss, train_acc = cnn.evaluate(training_set)
print('Training accuracy:', train_acc)
# Out:
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 337s 153ms/step - accuracy: 0.9919 - loss: 0.0252
# Training accuracy: 0.9925030469894409

# %%
#Validation set Accuracy
val_loss, val_acc = cnn.evaluate(validation_set)
print('Validation accuracy:', val_acc)
# Out:
# 550/550 ━━━━━━━━━━━━━━━━━━━━ 84s 152ms/step - accuracy: 0.9664 - loss: 0.1173
# Validation accuracy: 0.9676758646965027

# %%
cnn.save('trained_plant_disease_model.keras')

# %%
model.save(r'C:\Users\user\Plant_Disease\Trained_plant_Disease.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
training_history.history #Return Dictionary of history
# Out:
# {'accuracy': [0.6138274669647217,
#   0.8616828918457031,
#   0.9169926643371582,
#   0.9407497048377991,
#   0.9571520090103149,
#   0.9656020998954773,
#   0.9727007746696472,
#   0.9757593274116516,
#   0.9799132347106934,
#   0.9825876951217651],
#  'loss': [1.3053841590881348,
#   0.4351373314857483,
#   0.25720614194869995,
#   0.17826637625694275,
#   0.13293956220149994,
#   0.10749934613704681,
#   0.08216823637485504,
#   0.07427413761615753,
#   0.06195259466767311,
#   0.05446648225188255],
#  'val_accuracy': [0.8528340458869934,
#   0.9091736674308777,
#   0.9401889443397522,
#   0.9443432688713074,
#   0.954757571220398,
#   0.9620987772941589,
#   0.9636922478675842,
#   0.9570339322090149,
#   0.9661962389945984,
#   0.9676758646965027],
#  'val_loss': [0.46317610144615173,
#   0.27741000056266785,
#   0.1819971203804016,
#   0.16758064925670624,
#   0.14509989321231842,
#   0.12501971423625946,
#   0.1169988214969635,
#   0.1368095874786377,
#   0.11566454917192459,
#   0.11177998036146164]}

# %%
#Recording History in json
import json
with open('training_hist.json','w') as f:
  json.dump(training_history.history,f)

# %%
print(training_history.history.keys())
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
epochs = [i for i in range(1,11)]
plt.plot(epochs,training_history.history['accuracy'],color='red',label='Training Accuracy')
plt.plot(epochs,training_history.history['val_accuracy'],color='blue',label='Validation Accuracy')
plt.xlabel('No. of Epochs')
plt.title('Visualization of Accuracy Result')
plt.legend()
plt.show()

# %%
class_name = validation_set.class_names

# %%
test_set = tf.keras.utils.image_dataset_from_directory(
    r'C:/Users/user/archive/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=1,
    image_size=(128, 128),
    shuffle=False,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 17572 files belonging to 38 classes.

# %%
y_pred = cnn.predict(test_set)
predicted_categories = tf.argmax(y_pred, axis=1)
# Out:
# 17572/17572 ━━━━━━━━━━━━━━━━━━━━ 264s 15ms/step

# %%
true_categories = tf.concat([y for x, y in test_set], axis=0)
Y_true = tf.argmax(true_categories, axis=1)

# %%
Y_true
# Out:
# <tf.Tensor: shape=(17572,), dtype=int64, numpy=array([ 0,  0,  0, ..., 37, 37, 37], dtype=int64)>

# %%
predicted_categories
# Out:
# <tf.Tensor: shape=(17572,), dtype=int64, numpy=array([ 0,  0,  0, ..., 37, 37, 37], dtype=int64)>

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm = confusion_matrix(Y_true,predicted_categories)

# %%
# Precision Recall Fscore
print(classification_report(Y_true,predicted_categories,target_names=class_name))
# Out:
#                                                     precision    recall  f1-score   support
#
#                                 Apple___Apple_scab       0.96      0.96      0.96       504
#                                  Apple___Black_rot       0.98      1.00      0.99       497
#                           Apple___Cedar_apple_rust       0.99      0.95      0.97       440
#                                    Apple___healthy       0.97      0.95      0.96       502
#                                Blueberry___healthy       0.98      0.99      0.98       454
#           Cherry_(including_sour)___Powdery_mildew       0.98      0.97      0.97       421
#                  Cherry_(including_sour)___healthy       0.98      0.99      0.98       456
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.92      0.93      0.93       410
#                        Corn_(maize)___Common_rust_       0.98      0.99      0.99       477
#                Corn_(maize)___Northern_Leaf_Blight       0.97      0.92      0.95       477
#                             Corn_(maize)___healthy       0.99      1.00      0.99       465
#                                  Grape___Black_rot       0.98      0.99      0.98       472
#                       Grape___Esca_(Black_Measles)       0.99      0.98      0.99       480
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       0.99      1.00      0.99       430
#                                    Grape___healthy       0.99      0.99      0.99       423
#           Orange___Haunglongbing_(Citrus_greening)       0.99      0.97      0.98       503
#                             Peach___Bacterial_spot       0.95      0.99      0.97       459
#                                    Peach___healthy       0.99      1.00      0.99       432
#                      Pepper,_bell___Bacterial_spot       0.98      0.97      0.98       478
#                             Pepper,_bell___healthy       0.97      0.96      0.96       497
#                              Potato___Early_blight       0.91      0.99      0.95       485
#                               Potato___Late_blight       0.98      0.91      0.94       485
#                                   Potato___healthy       0.95      0.98      0.97       456
#                                Raspberry___healthy       0.98      1.00      0.99       445
#                                  Soybean___healthy       0.92      1.00      0.96       505
#                            Squash___Powdery_mildew       0.92      1.00      0.96       434
#                           Strawberry___Leaf_scorch       1.00      0.97      0.98       444
#                               Strawberry___healthy       0.98      1.00      0.99       456
#                            Tomato___Bacterial_spot       0.99      0.95      0.97       425
#                              Tomato___Early_blight       0.88      0.93      0.90       480
#                               Tomato___Late_blight       0.96      0.84      0.90       463
#                                 Tomato___Leaf_Mold       0.98      0.98      0.98       470
#                        Tomato___Septoria_leaf_spot       0.93      0.92      0.92       436
#      Tomato___Spider_mites Two-spotted_spider_mite       0.97      0.97      0.97       435
#                               Tomato___Target_Spot       0.97      0.88      0.92       457
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.99      0.99      0.99       490
#                       Tomato___Tomato_mosaic_virus       0.97      0.99      0.98       448
#                                   Tomato___healthy       0.98      0.99      0.99       481
#
#                                           accuracy                           0.97     17572
#                                          macro avg       0.97      0.97      0.97     17572
#                                       weighted avg       0.97      0.97      0.97     17572

# %%
plt.figure(figsize=(40, 40))
sns.heatmap(cm,annot=True,annot_kws={"size": 10})

plt.xlabel('Predicted Class',fontsize = 20)
plt.ylabel('Actual Class',fontsize = 20)
plt.title('Plant Disease Prediction Confusion Matrix',fontsize = 25)
plt.show()
